# %%
# %sql
optimize demoworkspace2.aura_raw.store_sales

# %%
# %sql
describe history demoworkspace2.aura_raw.store_sales

# %%
# %sql
optimize demoworkspace2.aura_raw.store_sales
zorder by (product_category,store_id)

# %%
# %sql
describe history demoworkspace2.aura_raw.store_sales

# %%
# %sql
vacuum demoworkspace2.aura_raw.store_sales

# %%
# %sql
SET spark.databricks.delta.retentionDurationCheck.enabled = false;

# %%
# %sql
vacuum demoworkspace2.aura_raw.store_sales RETAIN 0 HOURS

# %%
# %sql
describe history demoworkspace2.aura_raw.store_sales

# %%
table_info = spark.sql("DESCRIBE DETAIL demoworkspace2.aura_raw.store_sales").collect()[0]

all_files = dbutils.fs.ls(table_path)
display(all_files)
