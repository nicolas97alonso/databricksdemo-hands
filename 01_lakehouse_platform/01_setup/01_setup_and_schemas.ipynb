# %% [markdown]
# # Setup and schema creation
#
# This notebook initializes the workspace objects needed for the demo setup.
#
# What this notebook does:
# * selects the target catalog
# * creates the raw and gold schemas
# * switches into the working schema
# * validates the final schema configuration
#
# Expected outcome:
# * `demoworkspace.aura_raw`
# * `demoworkspace.aura_gold`
#
# Notes:
# * run the SQL cells from top to bottom to keep the catalog and schema context clear
# * the validation cells at the end confirm the active schema and the schema metadata

# %% [markdown]
# ## Create demo schemas
#
# Switch to the target catalog and create the schemas used in the rest of the demo.

# %%
# %sql 
use catalog demoworkspace;

# %%
# %sql
create schema if not exists aura_raw;
create schema if not exists aura_gold;

# %%
# %sql
show schemas;

# %%
# %sql
show current schema;

# %% [markdown]
# ## Set the working schema
#
# Move into `aura_raw` so subsequent objects are created in the intended schema.

# %%
    # %sql 
    use schema aura_raw;

# %%
# %sql
show current schema;

# %% [markdown]
# ## Validate the setup
#
# Confirm the active schema and inspect the schema metadata after creation.

# %%
# %sql
describe schema extended aura_raw;

# %% [markdown]
# ## Next steps
#
# After this notebook succeeds, continue with table creation or data ingestion into the `aura_raw` schema.
